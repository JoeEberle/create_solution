# %% [markdown]
#  ![unzip_automation.png](attachment:4f9369f7-b272-4af0-a08b-f4dc6406749a.png)

# %% [markdown]
# # Create Solution
# #### by Joe Eberle started on 05-23-2023 - https://github.com/JoeEberle/ - josepheberle@outlook.com

# %% [markdown]
# #### step 0 - First one time setup  - Pip install any libraries you dont already have - on

# %%
first_install = False 
if first_install:
    # !pip install schedule
    # !pip install zipp

# %%
import os
import schedule
from datetime import datetime
import time
import zipfile
print(f"Libraries Imported succesfully on {datetime.now().date()} at {datetime.now().time()}")
# Out:
# Libraries Imported succesfully on 2024-03-06 at 23:57:49.420609

# %%
path_to_zipfile = r"C://infrastructure//documentation"
path_to_store_unzipped_file = r"C://infrastructure//documentation//unzipped"
zipfile_name = 'documentation_system_information.zip'
full_zipfile_name = path_to_zipfile+ '//' + zipfile_name
gcasa = False
if gcasa:
    path_to_zipfile = r"N:\\power BI\\"
    zipfile_name = 'powerBIdownload.zip'
    path_to_store_unzipped_ile = r"N:\\powerBIdownload\\"
    full_zipfile_name = path_to_zipfile+ '//' + zipfile_name

print(f"Setup to unzip file: {full_zipfile_name}")
# Out:
# Setup to unzip file: C://infrastructure//documentation//documentation_system_information.zip

# %%
directory_path = r'c:\reports\high_risk_high_need'

# Create the directory if it doesn't exist
if not os.path.exists(directory_path):
    os.makedirs(directory_path)
    print(f"Directory '{directory_path}' created successfully.")
else:
    print(f"Directory '{directory_path}' already exists.")

# %%
def create_directory(directory_path): 
    if not os.path.exists(directory_path):
        os.makedirs(directory_path)
        result = f"Directory '{directory_path}' created successfully." 
    else:
        result = f"Directory '{directory_path}' already exists." 
    return(result)

# %%
create_directory(path_to_store_unzipped_file)
# Out:
# "Directory 'C://infrastructure//documentation//unzipped' already exists."

# %%
testing_zip_location = True
if testing_zip_location: 
    os.chdir(path_to_zipfile) 
    print(f"Listing files in directory{path_to_zipfile} ")
    for idx, filename in enumerate(os.listdir()): 
        print(f"File#{idx} Name:{filename} ")
# Out:
# Listing files in directoryC://infrastructure//documentation
# File#0 Name:configuring_settings.doc
# File#1 Name:configuring_sttings_documentation.doc
# File#2 Name:documentation_logging_and_debugging.doc
# File#3 Name:documentation_system_information.doc
# File#4 Name:documentation_system_information.zip
# File#5 Name:documentation_word_cloud.doc
# File#6 Name:library_installer.doc
# File#7 Name:unzipped
# File#8 Name:unzip_automation.log
# File#9 Name:unzip_automation_history.log

# %%
os.listdir()
# Out:
# ['configuring_settings.doc',
#  'configuring_sttings_documentation.doc',
#  'documentation_logging_and_debugging.doc',
#  'documentation_system_information.doc',
#  'documentation_system_information.zip',
#  'documentation_word_cloud.doc',
#  'library_installer.doc',
#  'unzipped',
#  'unzip_automation.log',
#  'unzip_automation_history.log']

# %%
with zipfile.ZipFile(full_zipfile_name) as f:
    f.extractall(path_to_store_unzipped_file)

# %% [markdown]
# ## Optional Step 0 - Intitiate Configuration Settings and name the overall solution

# %%
import configparser 
config = configparser.ConfigParser()
cfg = config.read('config.ini')  

solution_name = 'unzip_automation'

# %% [markdown]
# ## Optional Step 0 - Intitiate Logging

# %%
# Establish the Python Logger  
import logging # built in python library that does not need to be installed 
import quick_logger as ql

global start_stime 
start_time = ql.set_start_time()
logging = ql.create_logger_start(solution_name, start_time) 
ql.set_speaking_log(True)
ql.set_speaking_steps(False)
ql.pvlog('info',f'Process {solution_name} Step 0 - Initializing and starting Logging Process.')
# Out:
# Process unzip_automation Step 0 - Initializing and starting Logging Process.

# %% [markdown]
# ## Step 1 - create functions to check for data files, directories, or mapped drives

# %%
ql.pvlog('info',f'Process {solution_name} - Step 1 - create watch dog functions to check for data files') 

def check_file_existence(directory, filename):
    file_path = os.path.join(directory, filename)
    if os.path.exists(file_path):
        print("File exists in the specified directory.")
    else:
        print("File does not exist in the specified directory.")

def check_mapped_drive_existence(drive_letter):
    drive_path = drive_letter + ":\\"
    if os.path.exists(drive_path):
        print("Mapped drive exists.")
    else:
        print("Mapped drive does not exist.")

def check_directory_existence(directory):
    if os.path.exists(directory):
        print("Directory exists.")
    else:
        print("Directory does not exist.")
# Out:
# Process unzip_automation - Step 1 - create watch dog functions to check for data files

# %% [markdown]
# ## Step 2 - Test for file existence.

# %%
testing_and_developing = False

if testing_and_developing: 
    ql.pvlog('info',f'{solution_name} - Step 2 - Test an example file. Watch for existence') 
    # Check for mapped drive existence
    directory = "/path/to/directory"
    filename = "example.txt"
    check_file_existence(directory, filename)    

    # Check for mapped drive existence
    drive_letter = "Z"
    check_mapped_drive_existence(drive_letter)

    # Check for directory existence
    specific_directory = "/path/to/specific/directory"
    check_directory_existence(specific_directory)

# %%
def check_file_scheduler(directory, filename, interval_minutes=None, specific_time=None):
    if interval_minutes:
        schedule.every(interval_minutes).minutes.do(check_file_existence, directory=directory, filename=filename)
    elif specific_time:
        schedule.every().day.at(specific_time).do(check_file_existence, directory=directory, filename=filename)
    else:
        print("Invalid scheduler configuration.")

    while True:
        schedule.run_pending()
        time.sleep(1)

# %% [markdown]
# ## Optional Step 3 - Establish Schedule to file existence

# %%
testing_and_developing = False

if testing_and_developing: 
    ql.pvlog('info',f'{solution_name} - Step 3 - Establish Schedule to Test watchdog for file existence') 
    directory = "/path/to/directory"
    filename = "example.txt"
    
    # Check every 15 minutes
#     check_file_scheduler(directory, filename, interval_minutes=15)
    # Check every 1 minutes
    check_file_scheduler(directory, filename, interval_minutes=1)    

    # Check at a specific time of day (e.g., 9:30 AM)
#     check_file_scheduler(directory, filename, specific_time="09:30")

# %% [markdown]
# ## Step 0 - Process End - display log

# %%
# Calculate and classify the process performance 
status = ql.calculate_process_performance(solution_name, start_time) 
print(ql.append_log_file(solution_name))
# Out:
# 2024-03-06 23:57:49,540 - INFO - START unzip_automation =============================================
# 2024-03-06 23:57:49,540 - INFO - START unzip_automation Start Time = 2024-03-06 23:57:49
# 2024-03-06 23:57:49,540 - INFO - unzip_automation Step 0 - Initialize the configuration file parser
# 2024-03-06 23:57:49,652 - INFO - Imported existing <module 'comtypes.gen' from 'C:\\Users\\josep\\anaconda3\\lib\\site-packages\\comtypes\\gen\\__init__.py'>
# 2024-03-06 23:57:49,652 - INFO - Using writeable comtypes cache directory: 'C:\Users\josep\anaconda3\lib\site-packages\comtypes\gen'
# 2024-03-06 23:57:55,764 - INFO - Process unzip_automation Step 0 - Initializing and starting Logging Process.
# 2024-03-06 23:58:01,956 - INFO - Process unzip_automation - Step 1 - create watch dog functions to check for data files
# 2024-03-06 23:58:02,017 - INFO - PERFORMANCE unzip_automation The total process duration was:12.48
# 2024-03-06 23:58:02,017 - INFO - PERFORMANCE unzip_automation Stop Time = 2024-03-06 23:58:02
# 2024-03-06 23:58:02,017 - INFO - PERFORMANCE unzip_automation Low process duration less than 3 minutes:12.48
# 2024-03-06 23:58:02,017 - INFO - PERFORMANCE unzip_automation Performance optimization is optional
# 2024-03-06 23:58:02,017 - INFO - END unzip_automation =============================================

# %% [markdown]
# #### https://github.com/JoeEberle/ -- josepheberle@outlook.com
